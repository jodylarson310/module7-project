# %%
import matplotlib.pyplot as plt
import holoviews as hv
import hvplot
import hvplot.pandas
import geopandas as gpd
import pandas as pd
import numpy as np
import requests
import json
import time
from config import api_key
from scipy.stats import linregress
from pprint import pprint

# %%
artist = 'FooFighters'
dmaId = '264,324,385,336'
segment = 'Music'

events = requests.get(f'https://app.ticketmaster.com/discovery/v2/events.json?keyword={artist}&dmaId={dmaId}&segment={segment}&apikey={api_key}').json()

# %%
#open('test_output.json', 'w').write(json.dumps(events, indent=4))

# %%
# Create empty lists for each column
artist = []
date = []
city = []
state = []
country_list = []
min_price = []
max_price = []
latitude = []
longitude = []

for x in events['_embedded']['events']:
    
    artist_name = x['name']
    event_date = x['dates']['start']['localDate']
    event_city = x['_embedded']['venues'][0]['city']['name']
    country = x['_embedded']['venues'][0]['country']['countryCode']
    lat = x['_embedded']['venues'][0]['location']['latitude']
    long = x['_embedded']['venues'][0]['location']['longitude']

    artist.append(artist_name)
    date.append(event_date)
    city.append(event_city)
    country_list.append(country)
    
    if 'state' in x['_embedded']['venues'][0]:
        state.append(x['_embedded']['venues'][0]['state']['stateCode'])
    else:
        state.append(None)

    latitude.append(lat)
    longitude.append(long)

    if 'priceRanges' in x:
        min_price.append(x['priceRanges'][0]['min'])
        max_price.append(x['priceRanges'][0]['max'])
    else:
        min_price.append(None)
        max_price.append(None)

# Create the DataFrame using the lists
ff_events_df = pd.DataFrame({
    'Artist & Tour': artist,
    'Date': date,
    'City': city,
    'State': state,
    'Country': country_list,
    'Min Price': min_price,
    'Max Price': max_price,
    'Lat': latitude,
    'Lon': longitude
})

# Display the DataFrame
ff_events_df
# Out:
#                                         Artist & Tour        Date  \
# 0         Foo Fighters - Everything Or Nothing At All  2024-08-03
# 1         Foo Fighters - Everything Or Nothing At All  2024-08-18
# 2         Foo Fighters - Everything Or Nothing At All  2024-07-28
# 3         Foo Fighters - Everything Or Nothing At All  2024-08-07
# 4         Foo Fighters - Everything Or Nothing At All  2024-07-25
# 5         Foo Fighters - Everything Or Nothing At All  2024-07-19
# 6         Foo Fighters - Everything Or Nothing At All  2024-07-17
# 7         Foo Fighters - Everything Or Nothing At All  2024-07-23
# 8         Foo Fighters - Everything Or Nothing At All  2024-08-09
# 9         Foo Fighters - Everything Or Nothing At All  2024-08-11
# 10  Foo Fighters - Everything Or Nothing At All - ...  2024-07-21
# 11                                       Foo Fighters  2023-11-29
# 12                                       Foo Fighters  2024-01-20
# 13  Foo Fighters - EVERYTHING OR NOTHING AT ALL UK...  2024-06-13
# 14  Foo Fighters - EVERYTHING OR NOTHING AT ALL UK...  2024-06-15
# 15  Foo Fighters - EVERYTHING OR NOTHING AT ALL UK...  2024-06-17
# 16  Foo Fighters - EVERYTHING OR NOTHING AT ALL UK...  2024-06-20
# 17  Foo Fighters - EVERYTHING OR NOTHING AT ALL UK...  2024-06-22
# 18  Foo Fighters - EVERYTHING OR NOTHING AT ALL UK...  2024-06-25
# 19  Foo Fighters - EVERYTHING OR NOTHING AT ALL UK...  2024-06-27
#
#            City State Country  Min Price  Max Price          Lat  \
# 0        Denver    CO      US      36.00     175.50    39.743853
# 1       Seattle    WA      US      39.50     179.50    47.590333
# 2   Minneapolis    MN      US      39.50     179.50    44.981422
# 3     San Diego    CA      US      34.50     174.50  32.70709659
# 4    Cincinnati    OH      US      39.50     179.50  39.09755226
# 5        Queens    NY      US      39.50     179.50    40.758005
# 6        Queens    NY      US      39.50     179.50    40.758005
# 7       Hershey    PA      US      28.50     168.50    40.290715
# 8   Los Angeles    CA      US      59.50     179.50    34.012879
# 9   Los Angeles    CA      US      59.50     179.50    34.012879
# 10       Boston    MA      US        NaN        NaN   42.3464072
# 11        Perth    WA      AU       0.00     212.34   -31.950538
# 12     Auckland    NZ      NZ      90.90     320.90  -36.9199905
# 13   Manchester  None      GB      75.00     175.00    53.457224
# 14   Manchester  None      GB      75.00     175.00    53.457224
# 15      Glasgow  None      GB      56.25     186.80    55.825241
# 16       London  None      GB      60.50     214.00    51.536039
# 17       London  None      GB      60.50     214.00    51.536039
# 18      Cardiff  None      GB      50.00     175.00    51.477945
# 19   Birmingham  None      GB      50.00     175.00    52.508486
#
#               Lon
# 0     -105.020127
# 1      -122.33285
# 2       -93.27847
# 3   -117.15680771
# 4    -84.50756335
# 5      -73.844599
# 6      -73.844599
# 7      -76.660281
# 8     -118.284926
# 9     -118.284926
# 10    -71.0986584
# 11     115.865022
# 12    174.8134003
# 13      -2.287351
# 14      -2.287351
# 15      -4.253201
# 16      -0.014687
# 17      -0.014687
# 18       -3.18305
# 19      -1.884946

# %%
ff_events_df = ff_events_df.loc[ff_events_df["Country"] == "US"]

# %%
ff_events_df = ff_events_df.astype({
    "Artist & Tour": str,
    "Date": str,
    "City": str,
    "State": str,
    "Country": str,
    "Min Price": float,
    "Max Price": float,
    "Lat": float,
    "Lon": float
})

# %%
ff_events_df = ff_events_df.sort_values("Date")
ff_events_df
# Out:
#                                         Artist & Tour        Date  \
# 6         Foo Fighters - Everything Or Nothing At All  2024-07-17
# 5         Foo Fighters - Everything Or Nothing At All  2024-07-19
# 10  Foo Fighters - Everything Or Nothing At All - ...  2024-07-21
# 7         Foo Fighters - Everything Or Nothing At All  2024-07-23
# 4         Foo Fighters - Everything Or Nothing At All  2024-07-25
# 2         Foo Fighters - Everything Or Nothing At All  2024-07-28
# 0         Foo Fighters - Everything Or Nothing At All  2024-08-03
# 3         Foo Fighters - Everything Or Nothing At All  2024-08-07
# 8         Foo Fighters - Everything Or Nothing At All  2024-08-09
# 9         Foo Fighters - Everything Or Nothing At All  2024-08-11
# 1         Foo Fighters - Everything Or Nothing At All  2024-08-18
#
#            City State Country  Min Price  Max Price        Lat         Lon
# 6        Queens    NY      US       39.5      179.5  40.758005  -73.844599
# 5        Queens    NY      US       39.5      179.5  40.758005  -73.844599
# 10       Boston    MA      US        NaN        NaN  42.346407  -71.098658
# 7       Hershey    PA      US       28.5      168.5  40.290715  -76.660281
# 4    Cincinnati    OH      US       39.5      179.5  39.097552  -84.507563
# 2   Minneapolis    MN      US       39.5      179.5  44.981422  -93.278470
# 0        Denver    CO      US       36.0      175.5  39.743853 -105.020127
# 3     San Diego    CA      US       34.5      174.5  32.707097 -117.156808
# 8   Los Angeles    CA      US       59.5      179.5  34.012879 -118.284926
# 9   Los Angeles    CA      US       59.5      179.5  34.012879 -118.284926
# 1       Seattle    WA      US       39.5      179.5  47.590333 -122.332850

# %%
ff_events_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 6 to 1
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Artist & Tour  11 non-null     object
#  1   Date           11 non-null     object
#  2   City           11 non-null     object
#  3   State          11 non-null     object
#  4   Country        11 non-null     object
#  5   Min Price      10 non-null     float64
#  6   Max Price      10 non-null     float64
#  7   Lat            11 non-null     float64
#  8   Lon            11 non-null     float64
# dtypes: float64(4), object(5)
# memory usage: 880.0+ bytes

# %%
# Configure the map plot
map_plot = ff_events_df.hvplot.points(
    "Lon",
    "Lat",
    geo = True,
    tiles = "OSM",
    color = "City",
    frame_width = 800,
    frame_height = 600
)

map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (City)
